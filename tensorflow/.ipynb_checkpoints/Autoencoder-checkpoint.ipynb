# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("./mnist/data/", one_hot= True)

# 학습률
learning_rate = 0.01
# 학습 총횟수
training_epoch = 20
# 미니배치로 한번에 학습할 데이터 개수
batch_size = 100
# 입력값의 크기
n_hidden =256
# 사용할 MNIST 의 이미지 크기 
n_input = 28*28

# 비지도 학습이라 Y 값이 없음
X = tf.placeholder(tf.float32, [None, n_input])

# 인코더
# n_hidden개의 뉴런을 가진 은닉층
W_encode = tf.Variable(tf.random_normal([n_input, n_hidden]))
b_encode = tf.Variable(tf.random_normal([n_hidden]))
# 시그모이드 적용 n_input 보다 n_hidden 이 작아야함
encoder = tf.nn.sigmoid(tf.add(tf.matmul(X, W_encode), b_encode))

# 디코더
W_decode = tf.Variable(tf.random_normal([n_hidden, n_input]))
b_decode = tf.Variable(tf.random_normal([n_input]))
decoder = tf.nn.sigmoid(tf.add(tf.matmul(encoder, W_decode), b_decode))

cost = tf.reduce_mean(tf.pow(X - decoder, 2))
optimizer = tf.train.RMSPropOptimizer(learning_rate).minimize(cost)

init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

total_batch = int(mnist.train.num_examples / batch_size)

for epoch in range(training_epoch):
    total_cost = 0
    for i in range(total_batch):
        batch_xs, batch_ys = mnist.train.next_batch(batch_size)
        _, cost_val = sess.run([optimizer, cost], feed_dict ={X: batch_xs})
        total_cost += cost_val
        
    print('Epoch:', '%04d' % (epoch + 1),
         'Avg. cost =', '{:.4f}'.format(total_cost / total_batch))
    
print('최적화 완료!')

# 10개의 샘플을 가져와 디코딩
sample_size = 10
samples = sess.run(decoder,
                  feed_dict={X: mnist.test.images[:sample_size]})

fiㅎ, ax = plt.subplots(2, sample_size, figsize=(sample_size, 2))

for i in range(sample_size):
    ax[0][i].set_axis_off()
    ax[1][i].set_axis_off()
    ax[0][i].imshow(np.reshape(mnist.test.images[i], (28,28)))
    ax[1][i].imshow(np.reshape(samples[i], (28,28)))
    
plt.show()
# Out:
# Extracting ./mnist/data/train-images-idx3-ubyte.gz
# Extracting ./mnist/data/train-labels-idx1-ubyte.gz
# Extracting ./mnist/data/t10k-images-idx3-ubyte.gz
# Extracting ./mnist/data/t10k-labels-idx1-ubyte.gz
# Epoch: 0001 Avg. cpst = 0.1864
# Epoch: 0002 Avg. cpst = 0.0559
# Epoch: 0003 Avg. cpst = 0.0445
# Epoch: 0004 Avg. cpst = 0.0398
# Epoch: 0005 Avg. cpst = 0.0374
# Epoch: 0006 Avg. cpst = 0.0359
# Epoch: 0007 Avg. cpst = 0.0347
# Epoch: 0008 Avg. cpst = 0.0330
# Epoch: 0009 Avg. cpst = 0.0315
# Epoch: 0010 Avg. cpst = 0.0297
# Epoch: 0011 Avg. cpst = 0.0286
# Epoch: 0012 Avg. cpst = 0.0281
# Epoch: 0013 Avg. cpst = 0.0273
# Epoch: 0014 Avg. cpst = 0.0269
# Epoch: 0015 Avg. cpst = 0.0267
# Epoch: 0016 Avg. cpst = 0.0265
# Epoch: 0017 Avg. cpst = 0.0262
# Epoch: 0018 Avg. cpst = 0.0260
# Epoch: 0019 Avg. cpst = 0.0259
# Epoch: 0020 Avg. cpst = 0.0258
# 최적화 완료!
